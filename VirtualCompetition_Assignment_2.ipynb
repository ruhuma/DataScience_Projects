# %%
import pandas as pd
import numpy as np

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
           'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
            'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
            'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
labels= ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
#1. Create a DataFrame `df` from this dictionary `data` which has the index `labels`.
df = pd.DataFrame(data, index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#2. Display a summary of the basic information about this DataFrame and its data
#hint: there is a single method that can be called on the DataFrame*)."

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#3Return the first 3 rows of the DataFrame `df`.
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
#4.Display the 'animal' and 'age' columns from the DataFrame `df`
df[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
#5.Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'
print(df.iloc[[3,4,8], [0, 1]])
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
#6. Select only the rows where the number of visits is greater than 3.
df[df.visits>3]
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %%
#7. Select the rows where the age is missing, i.e. it is `NaN`.
df[df["age"].isna()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
#8.Select the rows where the animal is a cat *and* the age is less than 3."
df[(df.animal == "cat") & (df.age<3) ]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %%
#9.Select the rows where the age is between 2 and 4 (inclusive)

df[(df.age >= 2)&(df.age<=4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %%
#10. Change the age in row 'f' to 1.5.

df.loc['f','age'] = 1.5
#df.loc['f','age']

# %%
  # 11. Calculate the sum of all visits in `df` (i.e. the total number of visits)."
  df.visits.sum()
# Out:
# 19

# %%
#12.** Calculate the mean age for each different animal in `df`
ani_grp = df.groupby('animal')
pd.DataFrame(ani_grp['age'].mean())
# Out:
#         age
# animal
# cat     2.5
# dog     5.0
# snake   2.5

# %%
#13.** Append a new row 'k' to `df` with your choice of values for each column.
#Then delete that row to return the original DataFrame."

df.loc['k'] = ['dog',4,4,'yes']

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no
# k    dog  4.0       4      yes

# %%
#df.drop(labels=10,axis=0,inplace = True)
df.drop('k')
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#14.** Count the number of each type of animal in `df`
df['animal'].value_counts()
# Out:
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %%
#15.** Sort `df` first by the values in the 'age' in *decending* order,
#then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last)."
df.sort_values(by=['age','visits'], ascending=[False,True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# k    dog  4.0       4      yes
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %%
#16.** The 'priority' column contains the values 'yes' and 'no'.
#Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`."
df['priority'] = df['priority'].map({'yes': True, 'no': False})
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  1.5       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False
# k    dog  4.0       4      True

# %%
#17.In the 'animal' column, change the 'snake' entries to 'python'.
df['animal'] = df['animal'].replace('snake','python')
df
# Out:
#    animal  age  visits priority
# a     cat  2.5       1      yes
# b     cat  3.0       3      yes
# c  python  0.5       2       no
# d     dog  NaN       3      yes
# e     dog  5.0       2       no
# f     cat  2.0       3       no
# g  python  4.5       1       no
# h     cat  NaN       1      yes
# i     dog  7.0       2       no
# j     dog  3.0       1       no

# %%
#18Load the ny-flights dataset to Python
data = pd.read_csv('/content/ny-flights.csv')
data.head()
# Out:
#                fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0  2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1  2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2  2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3  2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4  2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
#
#   dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 0  LAX     914.0       14.0    1238.0       13.0        0.0
# 1  LAX    1157.0       -3.0    1523.0       13.0        0.0
# 2  LAX    1902.0        2.0    2224.0        9.0        0.0
# 3  PBI     722.0       -8.0    1014.0      -26.0        0.0
# 4  LAX    1347.0        2.0    1706.0        1.0        0.0
#
#                    arr                  dep
# 0  2014-01-01 12:38:00  2014-01-01 09:14:00
# 1  2014-01-01 15:23:00  2014-01-01 11:57:00
# ...

# %%
#19.** Which airline ID is present maximum times in the dataset"

all_airline_count = data['airline_id'].value_counts()
first_airline_id = all_airline_count.index.tolist()[0]
first_airline_count = all_airline_count.iloc[0]
print("Airline id:" ,first_airline_id,"Count:",first_airline_count)
# Out:
# Airline id: 20409 Count: 4902

# %%
#"**20.** Draw a plot between dep_delay and arr_delay"
import matplotlib.pyplot as plt

data.plot.scatter(x="dep_delay",y="arr_delay",s=10)
plt.xlabel("Departure delay")
plt.ylabel("Arrival delay")
# Out:
# Text(0, 0.5, 'Arrival delay')
